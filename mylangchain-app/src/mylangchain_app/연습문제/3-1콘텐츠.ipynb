# %%
import os
from pprint import pprint
from dotenv import load_dotenv

# LangChain 관련 모듈 import
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_upstage import UpstageEmbeddings, ChatUpstage
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA

# .env환경 변수
load_dotenv()

# --- 0단계: 문서 로드 ---
print(">>> 0단계: 문서를 로드합니다...")
# PyPDFLoader를 사용하여 PDF 문서를 로드합니다.
# 사용자의 디렉토리 구조에 맞춰 상대 경로를 설정했습니다.
loader = PyPDFLoader('../data/콘텐츠분쟁해결_사례.pdf')
documents = loader.load()
print(f"문서의 총 페이지 수: {len(documents)}")


# --- 1단계: 문서 분할 ---
print("\n>>> 1단계: 문서를 분할합니다...")
# 법률 문서의 구조적 특징을 고려한 구분자(separators)를 사용하여 문서를 분할합니다.
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=300,
    separators=[
        "\n【사건개요】",
        "\n【쟁점사항】",
        "\n【처리경위】",
        "\n【처리결과】",
        "\n■", "\n\n", "\n", ".", " ", ""
    ]
)
split_docs = text_splitter.split_documents(documents)
print(f"분할된 문서(청크)의 수: {len(split_docs)}")


# --- 2단계: 임베딩 모델 설정 ---
print("\n>>> 2단계: 임베딩 모델을 설정합니다...")
# Upstage의 solar-embedding-1-large 모델을 사용하여 텍스트를 벡터로 변환합니다.
embeddings = UpstageEmbeddings(model="solar-embedding-1-large")


# --- 3단계: 벡터 저장소(Vector Store) 및 검색기(Retriever) 설정 ---
print("\n>>> 3단계: 벡터 저장소를 만들고 검색기를 설정합니다...")
# 분할된 문서를 임베딩하여 FAISS 벡터 저장소에 저장합니다.
vectorstore = FAISS.from_documents(split_docs, embeddings)
# 벡터 저장소를 기반으로 검색기를 생성합니다. 상위 5개의 관련 문서를 검색합니다.
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 5}
)


# --- 4단계: LLM 설정 ---
print("\n>>> 4단계: LLM을 설정합니다...")
# Upstage의 Solar 모델을 LLM으로 사용합니다.
llm = ChatUpstage(
    model_name="solar-1-mini-chat", # solar-1-mini-chat 사용 (solar-pro는 현재 지원되지 않음)
    temperature=0.2
)


# --- 5단계: 법률 자문 프롬프트 작성 ---
print("\n>>> 5단계: 프롬프트를 작성합니다...")
prompt_template_str = """
당신은 콘텐츠 분야 전문 법률 자문가입니다.
아래 분쟁조정 사례들을 바탕으로 정확하고 전문적인 법률 조언을 제공해주세요.

관련 분쟁사례:
{context}

상담 내용: {question}

답변 가이드라인:
1. 제시된 사례들을 근거로 답변하세요
2. 관련 법령이나 조항이 있다면 명시하세요
3. 비슷한 사례의 처리경위와 결과를 참고하여 설명하세요
4. 실무적 해결방안을 단계별로 제시하세요
5. 사례에 없는 내용은 "제시된 사례집에서는 확인할 수 없습니다"라고 명시하세요

전문 법률 조언:"""

prompt = PromptTemplate.from_template(prompt_template_str)


# --- 6단계: QA 체인 생성 ---
print("\n>>> 6단계: QA 체인을 생성합니다...")
# RetrievalQA 체인을 생성하여 RAG 파이프라인을 완성합니다.
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    chain_type_kwargs={"prompt": prompt},
    return_source_documents=True
)


# --- 7단계: 테스트 질문 작성 ---
print("\n>>> 7단계: 테스트 질문을 준비합니다...")
test_questions = [
    "온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?",
    "인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?",
    "무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?",
    "미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?",
    "온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?"
]


# --- 8단계: 분쟁 유형 분류 함수 (선택) ---
def classify_dispute_type(query):
    game_keywords = ["게임", "아이템", "계정", "캐릭터", "레벨", "길드", "온라인게임"]
    elearning_keywords = ["강의", "온라인교육", "이러닝", "수강", "환불", "화상교육"]
    web_keywords = ["웹사이트", "무료체험", "자동결제", "구독", "사이트"]

    query_lower = query.lower()

    if any(keyword in query_lower for keyword in game_keywords):
        return "게임"
    elif any(keyword in query_lower for keyword in elearning_keywords):
        return "이러닝"
    elif any(keyword in query_lower for keyword in web_keywords):
        return "웹콘텐츠"
    else:
        return "기타"

# --- 테스트 실행 ---
print("\n" + "="*50)
print(" RAG 법률 자문 시스템 테스트 시작")
print("="*50 + "\n")

for i, question in enumerate(test_questions):
    dispute_type = classify_dispute_type(question)
    
    print(f"--- [질문 {i+1}] ---")
    print(f"유형: {dispute_type}")
    print(f"내용: {question}")
    
    # QA 체인 실행
    result = qa_chain.invoke(question)
    
    print("\n[답변]")
    pprint(result["result"])
    
    # print("\n[참조한 원문]")
    # for doc in result["source_documents"]:
    #     pprint(doc.page_content)
    #     print("-" * 20)
        
    print("\n" + "="*50 + "\n")
# Out:
# >>> 0단계: 문서를 로드합니다...
# 문서의 총 페이지 수: 109
#
# >>> 1단계: 문서를 분할합니다...
# 분할된 문서(청크)의 수: 104
#
# >>> 2단계: 임베딩 모델을 설정합니다...
#
# >>> 3단계: 벡터 저장소를 만들고 검색기를 설정합니다...
#
# >>> 4단계: LLM을 설정합니다...
#
# >>> 5단계: 프롬프트를 작성합니다...
#
# >>> 6단계: QA 체인을 생성합니다...
#
# >>> 7단계: 테스트 질문을 준비합니다...
#
# ==================================================
#  RAG 법률 자문 시스템 테스트 시작
# ==================================================
#
# --- [질문 1] ---
# 유형: 게임
# 내용: 온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?
#
# [답변]
# ('제시된 사례들을 근거로 답변드리겠습니다.\n'
#  '\n'
#  '1. 관련 법령 및 조항:\n'
#  '   - 민법 제250조(도품, 유실물에 대한 특례)\n'
#  '   - 민법 제251조(양수인의 선의취득)\n'
#  '   - 게임회사의 이용약관(특히, 이용자의 의무 및 아이템 복구 관련 규정)\n'
#  '\n'
#  '2. 비슷한 사례의 처리경위와 결과:\n'
#  '   - 사례 1(2006년): 시스템 오류로 아이템이 소멸되었으나, 계정 명의자가 아니어서 복구가 거부되었습니다.\n'
#  '   - 사례 2(2009년): 시스템 오류로 게임머니가 소실되었다고 주장했으나, 시스템 오류가 아닌 통신회선 또는 PC 오류로 판단되어 '
#  '복구가 거부되었습니다.\n'
#  '   - 사례 4(2006년): 프로그램 오류로 아이템이 소멸되었으나, 게임회사가 오류를 인정하고 복구를 해주었습니다.\n'
#  '\n'
#  '3. 실무적 해결방안:\n'
#  '   - 단계 1: 게임회사에 문의하여 시스템 오류 발생 시점, 오류 내용, 소멸된 아이템 정보 등을 자세히 기록하고 문의합니다.\n'
#  '   - 단계 2: 게임회사의 이용약관을 확인하고, 아이템 복구 관련 규정을 숙지합니다.\n'
#  '   - 단계 3: 게임회사의 고객센터를 통해 공식적으로 아이템 복구 요청을 합니다. 이때, 관련 증거(스크린샷, 게임 내 채팅 기록 '
#  '등)를 함께 제출합니다.\n'
#  '   - 단계 4: 게임회사의 답변이 만족스럽지 않거나 복구가 거부된 경우, 한국소비자원에 피해구제 신청을 고려합니다. 이때, 관련 '
#  '증거와 함께 피해 사실을 구체적으로 기술해야 합니다.\n'
#  '   - 단계 5: 한국소비자원의 중재 결과에도 만족하지 못할 경우, 법적 조치를 고려할 수 있습니다. 이때, 민법 제250조, '
#  '제251조 및 게임회사의 이용약관을 근거로 법적 자문을 구하는 것이 좋습니다.\n'
#  '\n'
#  '제시된 사례집에서는 확인할 수 없는 내용은 다음과 같습니다.\n'
#  '\n'
#  '- 게임회사의 구체적인 이용약관 내용\n'
#  '- 시스템 오류의 구체적인 원인 및 발생 시점\n'
#  '- 소멸된 아이템의 가치 및 구매 내역\n'
#  '- 게임회사의 공식적인 답변 및 처리 결과\n'
#  '- 한국소비자원의 중재 결과 및 법적 조치의 구체적인 절차 및 효과\n'
#  '\n'
#  '따라서, 위 단계별 해결방안을 참고하되, 구체적인 상황에 따라 추가적인 조치가 필요할 수 있습니다.')
#
# ==================================================
#
# --- [질문 2] ---
# 유형: 이러닝
# 내용: 인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?
#
# [답변]
# ('제시된 사례들을 근거로 답변드리겠습니다.\n'
#  '\n'
#  '1. 관련 법령 및 조항:\n'
#  '   - 방문판매 등에 관한 법률 제29조: 계약의 해지\n'
#  '   - 소비자기본법에 따른 소비자분쟁해결기준 (공정위고시, 인터넷콘텐츠업)\n'
#  '\n'
#  '2. 비슷한 사례의 처리경위와 결과:\n'
#  '   - 2007_인터넷교육서비스 중도해지 요구 사례에서, 피신청인이 공제한 위약금이 과도한 위약금에 해당하는지 여부가 쟁점이었습니다. '
#  '이 사례에서는 소비자분쟁해결기준에 따라 계약해지로 인한 손실을 현저하게 초과하는 위약금을 청구할 수 없다고 판단하였습니다.\n'
#  '   - 2008_온라인통신교육서비스 이용료 환급 요구2 사례에서도, 피신청인이 공제한 위약금이 과도한 위약금에 해당하는지 여부가 '
#  '쟁점이었습니다. 이 사례에서는 실제 지불한 금액을 계약금액으로 보아야 하며, 소비자분쟁해결기준에 따라 환급하는 것이 타당하다고 '
#  '판단하였습니다.\n'
#  '\n'
#  '3. 실무적 해결방안:\n'
#  '   - 먼저, 계약서상의 계약금액과 실제 지불한 금액이 일치하는지 확인하세요.\n'
#  '   - 계약서에 중도해지시 별도의 환급기준이 명시되어 있는지 확인하세요.\n'
#  '   - 만약 계약서에 별도의 환급기준이 없다면, 소비자분쟁해결기준에 따라 환급을 요구할 수 있습니다.\n'
#  '   - 과도한 위약금 요구에 대해서는 관련 법령 및 소비자분쟁해결기준을 근거로 이의를 제기할 수 있습니다.\n'
#  '   - 만약 피신청인이 과도한 위약금을 계속 요구한다면, 소비자보호원이나 법률사무소에 상담을 요청하여 추가적인 조치를 취할 수 '
#  '있습니다.\n'
#  '\n'
#  '제시된 사례집에서는 확인할 수 없는 내용은 다음과 같습니다:\n'
#  '- 구체적인 위약금 산정 기준\n'
#  '- 계약서의 구체적인 내용\n'
#  '- 피신청인의 구체적인 주장 및 근거\n'
#  '\n'
#  '위 답변은 제시된 사례들을 근거로 한 일반적인 법률 조언입니다. 구체적인 상황에 따라 법률적 판단이 달라질 수 있으므로, 추가적인 상담이 '
#  '필요한 경우 법률 전문가에게 문의하시기 바랍니다.')
#
# ==================================================
#
# --- [질문 3] ---
# 유형: 이러닝
# 내용: 무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?
#
# [답변]
# ('상담 내용: 무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?\n'
#  '\n'
#  '전문 법률 조언:\n'
#  '\n'
#  '1. 제시된 사례들을 근거로 답변하세요\n'
#  '\n'
#  "   제시된 사례들 중 '2010_무료 이벤트 후 자동 소액 결제 요금 환급요구' 사례에서 신청인은 무료 이벤트 후 자동 유료전환되어 "
#  '청구된 요금의 전액 환급을 요구하였으나, 분쟁조정 결과 피신청인의 책임을 50%로 제한하고 결제 금액의 50%를 환급하도록 '
#  '결정되었습니다.\n'
#  '\n'
#  '2. 관련 법령이나 조항이 있다면 명시하세요\n'
#  '\n'
#  "   관련 법령으로는 '약관의 규제에 대한 법률 제3조 약관의 작성 및 설명의무'와 '소비자기본법에 따른 소비자분쟁해결기준'이 있습니다. "
#  '약관의 규제에 대한 법률 제3조는 사업자가 약관을 작성할 때 명확하고 알기 쉽게 작성하고, 중요한 내용을 설명할 의무가 있다고 규정하고 '
#  '있습니다.\n'
#  '\n'
#  '3. 비슷한 사례의 처리경위와 결과를 참고하여 설명하세요\n'
#  '\n'
#  "   '2010_무료 이벤트 후 자동 소액 결제 요금 환급요구' 사례에서 피신청인은 무료 이벤트 기간 내 계약을 해지하지 않을 경우 자동 "
#  '유료전환 된다는 사실을 홈페이지 이벤트 화면에 고지하였으나, 활자가 매우 작아 쉽게 확인이 어려웠고, 계약 해지를 통지하지 않아 자동 '
#  '소액 결제 전환 시에도 신청인에게 유료로 전환된다는 사실이 고지되지 않았다는 점이 인정되었습니다. 이에 따라 피신청인의 책임을 50%로 '
#  '제한하고 결제 금액의 50%를 환급하도록 결정되었습니다.\n'
#  '\n'
#  '4. 실무적 해결방안을 단계별로 제시하세요\n'
#  '\n'
#  '   a. 계약서 및 약관 확인: 무료 이벤트 참여 시 제공받은 계약서 및 약관을 확인하여 자동 유료전환 조건과 환급 규정을 '
#  '파악합니다.\n'
#  '   \n'
#  '   b. 증거 수집: 무료 이벤트 참여 시 제공받은 이메일, 문자 메시지, 화면 캡처 등 관련 증거를 수집합니다.\n'
#  '   \n'
#  '   c. 사업자 연락: 사업자에게 무료 이벤트 후 자동 유료전환되어 청구된 요금의 환급을 요구합니다.\n'
#  '   \n'
#  '   d. 분쟁조정 신청: 사업자가 환급 요구를 거부하거나 합의가 이루어지지 않을 경우, 한국소비자원 또는 전자거래분쟁조정위원회에 '
#  '분쟁조정을 신청합니다.\n'
#  '   \n'
#  '   e. 법적 조치: 분쟁조정 결과에도 만족스러운 해결이 이루어지지 않을 경우, 법적 조치를 고려할 수 있습니다.\n'
#  '\n'
#  '5. 사례에 없는 내용은 "제시된 사례집에서는 확인할 수 없습니다"라고 명시하세요\n'
#  '\n'
#  '   제시된 사례집에서는 무료 이벤트 후 자동 유료전환되어 청구된 요금의 전액 환급이 인정된 사례는 확인할 수 없습니다. 그러나 '
#  '피신청인의 책임을 제한하고 일부 환급이 이루어진 사례는 확인할 수 있습니다.')
#
# ==================================================
#
# --- [질문 4] ---
# 유형: 게임
# 내용: 미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?
#
# [답변]
# ('미성년자가 부모 동의 없이 게임 아이템을 구매한 경우, 환불받을 수 있는 가능성이 있습니다. 제시된 사례들을 근거로 답변드리겠습니다.\n'
#  '\n'
#  '1. **관련 법령 및 조항**:\n'
#  '   - **민법 제5조**: 미성년자의 능력에 대해 규정하고 있습니다. 미성년자는 법률행위를 할 때 법정대리인의 동의를 받아야 '
#  '합니다.\n'
#  '   - **민법 제17조**: 무능력자의 사술에 대해 규정하고 있습니다. 미성년자가 상대방에게 자신을 성인으로 믿게 하여 계약을 체결한 '
#  '경우, 이는 사술행위로 간주될 수 있습니다.\n'
#  '\n'
#  '2. **비슷한 사례의 처리경위와 결과**:\n'
#  '   - 사례 1: 미성년자가 타인의 명의를 도용하여 결제한 경우, 부모의 책임과 게임사의 책임을 고려하여 일부 환불이 이루어졌습니다.\n'
#  '   - 사례 2: 미성년자가 부모 동의 없이 결제한 경우, 게임사는 미성년자 아이디로 이용된 금액에 한하여 취소 처리하였습니다.\n'
#  '   - 사례 3: 미성년자가 부모의 정보를 이용하여 결제한 경우, 부모의 책임과 게임사의 책임을 고려하여 일부 환불이 이루어졌습니다.\n'
#  '\n'
#  '3. **실무적 해결방안**:\n'
#  '   - **1단계**: 게임사에 연락하여 미성년자의 결제 사실을 알리고 환불을 요청합니다. 이때, 미성년자의 나이와 결제 내역을 증명할 '
#  '수 있는 자료를 준비해야 합니다.\n'
#  '   - **2단계**: 게임사가 환불을 거부하는 경우, 소비자보호원이나 전자거래분쟁조정위원회에 분쟁조정을 신청할 수 있습니다. 이때, '
#  '관련 법령과 사례를 근거로 주장을 펼칠 수 있습니다.\n'
#  '   - **3단계**: 분쟁조정이 실패할 경우, 법적 조치를 고려할 수 있습니다. 이때, 법률 전문가의 도움을 받는 것이 좋습니다.\n'
#  '\n'
#  '4. **주의사항**:\n'
#  '   - 미성년자가 상대방에게 자신을 성인으로 믿게 하여 계약을 체결한 경우, 사술행위로 간주되어 환불이 어려울 수 있습니다.\n'
#  '   - 미성년자의 결제 행위가 부모의 동의 없이 이루어졌음을 증명할 수 있는 자료를 준비하는 것이 중요합니다.\n'
#  '\n'
#  '제시된 사례집에서는 확인할 수 없는 내용은 법률 전문가의 도움을 받아 해결하는 것이 좋습니다.')
#
# ==================================================
#
# --- [질문 5] ---
# 유형: 기타
# 내용: 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?
#
# [답변]
# ('제시된 사례들을 근거로 답변드리겠습니다.\n'
#  '\n'
#  '1. 관련 법령: 방문판매 등에 관한 법률 제29조(계약의 해지) 및 제30조(계약의 해지 또는 해제의 효과와 위약금 등)가 '
#  '적용됩니다.\n'
#  '\n'
#  '2. 비슷한 사례의 처리경위와 결과:\n'
#  '   - 2007_온라인통신교육서비스 대금 환급 요구2 사례에서, 청구인은 서비스 내용이 광고와 다르게 제공되었다고 주장하며 계약을 '
#  '해지하였습니다. 이 경우, 법원은 계약 해지를 인정하고 소비자분쟁해결기준에 따라 환급을 결정하였습니다.\n'
#  '   - 2010_화상불량으로 중도 해지한 인터넷강의 환급 요구 사례에서도, 서비스 품질 문제로 인해 계약을 해지한 사례가 있습니다. 이 '
#  '경우에도 계약 해지가 인정되었고, 소비자분쟁해결기준에 따라 환급이 이루어졌습니다.\n'
#  '\n'
#  '3. 실무적 해결방안:\n'
#  '   a. 먼저, 온라인 교육 서비스 제공자에게 계약 해지를 서면으로 통보해야 합니다. 이때, 계약 해지의 사유를 명확히 기재해야 '
#  '합니다.\n'
#  '   b. 계약 해지 통보 후, 서비스 제공자가 계약 해지를 인정하고 환급 절차를 진행하지 않을 경우, 소비자보호원에 분쟁 조정을 신청할 '
#  '수 있습니다.\n'
#  '   c. 소비자보호원에서 분쟁 조정을 통해 해결이 되지 않을 경우, 법원에 소액심판청구를 제기하여 계약 해지와 환급을 요구할 수 '
#  '있습니다.\n'
#  '\n'
#  '4. 주의사항:\n'
#  '   - 계약 해지 시, 계약서에 기재된 계약 해지 절차를 따라야 합니다.\n'
#  '   - 계약 해지 통보 시, 계약 해지의 사유를 명확히 기재해야 합니다.\n'
#  '   - 소비자보호원에 분쟁 조정을 신청할 경우, 관련 증거 자료(계약서, 광고 자료, 서비스 이용 내역 등)를 준비해야 합니다.\n'
#  '\n'
#  '제시된 사례집에서는 확인할 수 없는 내용은 다음과 같습니다.\n'
#  '- 구체적인 환급 금액 산정 방법\n'
#  '- 계약 해지 통보 후 서비스 제공자의 대응 방식\n'
#  '- 법원에서 계약 해지를 인정한 구체적인 이유\n'
#  '\n'
#  '따라서, 위의 실무적 해결방안을 참고하여 진행하시되, 구체적인 상황에 따라 법률 전문가의 도움을 받으시는 것이 좋습니다.')
#
# ==================================================
